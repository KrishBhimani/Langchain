# %%
from langchain_ollama import OllamaEmbeddings

# %%
embedding=OllamaEmbeddings(model="llama3.2")
result=embedding.embed_documents(["This is my first embedding program",
                           "Ollama embedddings are great"])
result[0]
embedding.embed_query("Alpha is the first greek symbol")
embedding
# Out:
# OllamaEmbeddings(model='llama3.2', base_url=None, client_kwargs={})

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
with open("speech.txt") as f:
    speech=f.read()
text_splitter=RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
docs=text_splitter.create_documents([speech])
docs
# Out:
# [Document(metadata={}, page_content='The world must be made safe for democracy. Its peace must be planted upon the tested foundations of political liberty. We have no selfish ends to serve. We desire no conquest, no dominion. We seek no indemnities for ourselves, no material compensation for the sacrifices we shall freely make. We are but one of the champions of the rights of mankind. We shall be satisfied when those rights have been made as secure as the faith and the freedom of nations can make them.'),
#  Document(metadata={}, page_content='Just because we fight without rancor and without selfish object, seeking nothing for ourselves but what we shall wish to share with all free peoples, we shall, I feel confident, conduct our operations as belligerents without passion and ourselves observe with proud punctilio the principles of right and of fair play we profess to be fighting for.\n\n…'),
# ...

# %%
from langchain_community.vectorstores import Chroma
db=Chroma.from_documents(docs,embedding)
db

# %%
len(result[0])
# Out:
# 3072

# %%
query="It will be all the easier for us to conduct ourselves"
retrieved_results=db.similarity_search(query)
print(retrieved_results)
# Out:
# [Document(metadata={}, page_content='It will be all the easier for us to conduct ourselves as belligerents in a high spirit of right and fairness because we act without animus, not in enmity toward a people or with the desire to bring any injury or disadvantage upon them, but only in armed opposition to an irresponsible government which has thrown aside all considerations of humanity and of right and is running amuck. We are, let me'), Document(metadata={}, page_content='here and there and without countenance except from a lawless and malignant few.'), Document(metadata={}, page_content='have been made as secure as the faith and the freedom of nations can make them.'), Document(metadata={}, page_content='and shall desire nothing so much as the early reestablishment of intimate relations of mutual advantage between us—however hard it may be for them, for the time being, to believe that this is spoken from our hearts.')]

# %%
embedding.embed_query("What is the second letter of Greek alphabet ")
# Out:
# [-0.01592517,
#  -0.0037361586,
#  -0.011153779,
#  0.011999663,
#  0.026722547,
#  0.0034453273,
#  -0.014221477,
#  0.022618387,
#  -0.018494785,
#  -0.0015083278,
#  -0.008235269,
#  -0.02136105,
#  0.0066471975,
#  0.024982467,
#  -0.0077077397,
#  -0.029022044,
#  0.015896842,
#  -0.0013016281,
#  -0.017856846,
#  0.009783725,
#  0.0050962605,
#  -0.0005378028,
#  0.022107616,
#  0.0040587024,
#  0.043184508,
#  0.0006753667,
#  -0.026616776,
#  -0.024442391,
#  0.006966693,
#  0.014789578,
#  0.014453387,
#  -0.0031081485,
#  -0.025948057,
#  0.008343205,
#  0.005348295,
#  -0.0039516813,
#  0.0030567506,
#  0.002733973,
#  -0.003832413,
#  -0.0009747325,
#  0.010937628,
#  -0.012476048,
#  0.028234506,
#  0.04279939,
#  -0.027926875,
#  -0.021369606,
#  -0.0017979293,
#  -0.05299344,
#  0.011127623,
#  0.007216512,
#  0.020974314,
#  0.012525993,
#  -0.029061396,
#  0.0026876226,
#  -0.007604914,
#  -0.010709685,
#  0.024598839,
#  -0.021271694,
#  0.007055942,
# ...

# %%
embeddings=OllamaEmbeddings(model="mxbai-embed-large")
text = "This is a test document."
query_result = embeddings.embed_query(text)
query_result
# Out:
# [0.007117519,
#  -0.018590678,
#  0.055760168,
#  0.024307286,
#  -0.051251218,
#  -0.002190649,
#  -0.0024629792,
#  -0.008720675,
#  0.022042284,
#  0.055229098,
#  0.013430334,
#  0.026520172,
#  0.026847223,
#  0.0071607926,
#  -0.020762786,
#  0.01297582,
#  -0.022497898,
#  0.031169048,
#  -0.030872557,
#  -0.028521089,
#  -0.04215414,
#  0.014367013,
#  -0.053481016,
#  -0.019486986,
#  -0.025108047,
#  0.035283998,
#  -0.012707751,
#  0.004310859,
#  0.067174196,
#  0.01888871,
#  -0.0041255048,
#  0.0157801,
#  -0.03596278,
#  -0.04715787,
#  0.020431355,
#  -0.043369655,
#  0.062309846,
#  -0.035117075,
#  0.0022330307,
#  -0.03196723,
#  0.004514898,
#  0.009761448,
#  0.042865787,
#  -0.034261726,
#  -0.08437776,
#  -0.04422766,
#  -0.0148024475,
#  -0.008097354,
#  -0.027712591,
#  -0.027548442,
#  0.014845075,
#  0.030854946,
#  -0.010872568,
#  -0.035570264,
#  0.0006135472,
#  -0.020550778,
#  -0.02429575,
#  -0.02467549,
#  -0.03625689,
#  0.0653583,
#  0.05242385,
# ...

# %%
# from langchain.schema import Document
# docs = [
#     Document(page_content="This is a test document.", metadata={"source": "doc1"}),
#     Document(page_content="Another example document.", metadata={"source": "doc2"}),
# ]

# # Create the Chroma database
# db1 = Chroma.from_documents(docs, embeddings)

# # Confirm the database creation
# print(db1)
# Out:
# ---------------------------------------------------------------------------
# InvalidDimensionException                 Traceback (most recent call last)
# Cell In[55], line 8
#       2 docs = [
#       3     Document(page_content="This is a test document.", metadata={"source": "doc1"}),
#       4     Document(page_content="Another example document.", metadata={"source": "doc2"}),
#       5 ]
#       7 # Create the Chroma database
# ----> 8 db1 = Chroma.from_documents(docs, embeddings)
#      10 # Confirm the database creation
#      11 print(db1)
#
# File c:\documents\GEN AI\LLM\venv\lib\site-packages\langchain_community\vectorstores\chroma.py:887, in Chroma.from_documents(cls, documents, embedding, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     885 texts = [doc.page_content for doc in documents]
#     886 metadatas = [doc.metadata for doc in documents]
# --> 887 return cls.from_texts(
#     888     texts=texts,
# ...

# %%
from langchain_community.vectorstores import Chroma

db1=Chroma.from_documents(docs, embeddings)
db1
# Out:
# ---------------------------------------------------------------------------
# InvalidDimensionException                 Traceback (most recent call last)
# Cell In[47], line 3
#       1 from langchain_community.vectorstores import Chroma
# ----> 3 db1=Chroma.from_documents(docs, embeddings)
#       4 db1
#
# File c:\documents\GEN AI\LLM\venv\lib\site-packages\langchain_community\vectorstores\chroma.py:887, in Chroma.from_documents(cls, documents, embedding, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     885 texts = [doc.page_content for doc in documents]
#     886 metadatas = [doc.metadata for doc in documents]
# --> 887 return cls.from_texts(
#     888     texts=texts,
#     889     embedding=embedding,
#     890     metadatas=metadatas,
#     891     ids=ids,
#     892     collection_name=collection_name,
#     893     persist_directory=persist_directory,
#     894     client_settings=client_settings,
# ...

# %%
query="The world must be made safe for democracy"
retrieved_results=db1.similarity_search(query)
print(retrieved_results)

# %%
embeddings
# Out:
# OllamaEmbeddings(model='mxbai-embed-large', base_url=None, client_kwargs={})
